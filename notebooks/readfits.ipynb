# %% [markdown]
# #  PYTHON入门教程:
# https://www.liaoxuefeng.com/wiki/1016959663602400

# %% [markdown]
# # 变量的匈牙利命名法:
# * 命名应体现该变量的意义，不要怕长
# * 避免像a,b,c这样的命名
# * 变量中不能出现空格，用首字母大写的方式区分不同单词
#
# e.g. <br>
# thisIsAVariable <br>
# CatAge

# %% [markdown]
# # use *Markdown* **A LOT** <br>
#
# * google "Jupyer Markdown Cheatsheet"
#
# https://www.ibm.com/docs/en/watson-studio-local/1.2.3?topic=notebooks-markdown-jupyter-cheatsheet
#
# ## Example
# ***
#
#
# <div class="alert alert-block alert-info">
# Also you can put something in a box
# </div>
# * table
#
# ---
#
# | Stretch/Untouched | ProbDistribution | Accuracy |
# | --- | --- | --- |
# | Stretched | Gaussian | .843 |

# %% [markdown]
# # Section 1
# ## Subsection 11
# * list1
# * list2 <br>
#
# $\alpha_\nu=-1.4$
# $c=\frac{a}{b}$
# ![image.png](attachment:image.png)
# ## Subsection 12
# # Section 2
# ## Subsection 21
# # Section 3
# ## Subsection 31

# %% [markdown]
# ## Advantage of Markdown
# * __You can write down your ideas, working log here__
# * __integrate you data, calculation and text in one notebook__
#
#
# 1. For optically thick gas, due to Ly$\alpha$ trapping, photoionization from  the excited 2 $^2$S and 2 $^2$P levels is important.
# 2. Collional deexcitation begins to be important at  higher densities, the cooling rate at a given temperature is decreased, and the equilibrium temperature for a given radiation field is therefor somewhat increased
# 3. Higher temperature results in both higher collisional strength $\Upsilon$ and higher excited level population ($\propto exp(-\frac{\Delta E}{kT})$), and thus higher collisonal excitation rate $q_{12}$
# 4. For optically thin case, the cirtical density for 2 $^2$P is $n_c\sim10^{17}$ cm$^{-3}$, which for 2 $^2$S is $n_c \sim 10^9$ cm$^{-3}$. The high density in B1036-2257 predict a higher 2 $^2$S population than low density case.

# %% [markdown]
# # fitsio

# %%
# 尽量把所有的导入都放一起
from astropy.io import fits
from astropy.table import Table
import numpy as np

# %%
ls
# Out:
# DR14Q_SUBSET_TEST.fits*    readfits.ipynb*
# berk_composte.fits*        spec-6173-56238-0528.fits*
# figure_anatomy.png*

# %%
tbl=fits.open('../data/DR14Q_SUBSET_TEST.fits')

# %%
tbl.info()
# Out:
# Filename: ../data/DR14Q_SUBSET_TEST.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU       4   ()
#   1                1 BinTableHDU    231   1000R x 105C   [18A, D, D, J, I, J, I, 4A, D, D, 4A, D, D, D, I, D, D, D, K, K, K, K, K, K, I, I, I, 51J, 51J, 51J, 51A, D, D, I, A, I, I, A, 5D, 5D, 5D, 5D, D, 5D, D, D, D, D, D, D, D, D, D, D, D, E, D, D, D, D, D, D, E, I, D, D, E, I, D, D, E, I, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, D, 4A, 4A, D, E, D, D, D, D, D, D, D, D, I, D, D, D]

# %%
hdu1=tbl[1]
hdu1.header[0:10]
# Out:
# XTENSION= 'BINTABLE'           /Binary table written by MWRFITS v1.11
# BITPIX  =                    8 /Required value
# NAXIS   =                    2 /Required value
# NAXIS1  =                 1505 /Number of bytes per row
# NAXIS2  =                 1000 /Number of rows
# PCOUNT  =                    0 /Normally 0 (no varying arrays)
# GCOUNT  =                    1 /Required value
# TFIELDS =                  105 /Number of columns in table
# COMMENT
# COMMENT  *** End of mandatory fields ***

# %%
d1=hdu1.data

t=Table(d1)

# %%
t[0:10]
# Out:
# <Table length=10>
#     SDSS_NAME               RA          ... FIRST_SNR SDSS2FIRST_SEP
#       str18              float64        ...  float64     float64
# ------------------ -------------------- ... --------- --------------
# 000000.45+174625.4 0.001898274356335605 ...      -1.0           -1.0
# 000045.35+214115.4   0.1889701789202718 ...      -1.0           -1.0
# 000132.48+095310.6   0.3853720289941407 ...      -1.0           -1.0
# 000221.11-005922.2   0.5879734383033792 ...      -1.0           -1.0
# 000312.16-005439.3   0.8007047660018998 ...      -1.0           -1.0
# 000400.37+013203.6   1.0015700153701914 ...      -1.0           -1.0
# 000449.63+201951.2   1.2068312033802044 ...      -1.0           -1.0
# 000533.66+074649.7   1.3902790778566896 ...      -1.0           -1.0
# 000622.51+220653.7   1.5938191074345127 ...      -1.0           -1.0
# 000714.33+213235.7    1.809748526674412 ...      -1.0           -1.0

# %%
#string formatted to website
tmp=t['PLATE'].data
tmp1=t['MJD'].data

# %%
from astropy.io import fits
spec=fits.open("berk_composte.fits")
hdu0=spec[0]
d=hdu0.data
w=d[0]
f=d[1]
# Out:
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# Title: Composite Quasar Spectra From the Sloan Digital Sky Survey                [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# Authors: Vanden Berk D.E., Richards G.T., Bauer A., Strauss M.A.,                [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# Table: Median Composite Quasar Spectrum                                          [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# ================================================================================ [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# ...

# %%
spec.info()
# Out:
# Filename: berk_composte.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      29   (7754, 3)   float32

# %%
hdu0.header
# Out:
# SIMPLE  =                    T /Primary Header created by MWRFITS v1.4a
# BITPIX  =                  -32 /
# NAXIS   =                    2 /
# NAXIS1  =                 7754 /
# NAXIS2  =                    3 /
# EXTEND  =                    T /Extensions may be present
# Title: Composite Quasar Spectra From the Sloan Digital Sky Survey
# Authors: Vanden Berk D.E., Richards G.T., Bauer A., Strauss M.A.,
#          Schneider D.P., Heckman T.M., York D.G., Hall P.B., Fan X., Knapp G.R.,
#          Anderson S.F., Annis J., Bahcall N.A., Bernardi M., Briggs J.W.,
#          Brinkmann J., Brunner R., Burles S., Carey L., Castander F.J.,
#          Connolly A.J., Crocker J.H., Csabai I., Doi M., Finkbeiner D.,
#          Friedman S., Frieman J.A., Fukugita M., Gunn J.E., Hennessy G.S.,
#          Ivezic Z., Kent S., Kunszt P.Z., Lamb D.Q., Leger R.F., Long D.C.,
#          Loveday J., Lupton R.H., Meiksin A., Merelli A., Munn J.A.,
# ...

# %% [markdown]
# # Two ways of using matplotlib
# c.f. https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py
# 1. pyplot style
# 2. Object Oriented Style: e.g. fig,ax=pyplot.subplots()
# ![image.png](attachment:image.png)

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

# %% [markdown]
# ## Object Oriented Style

# %% [markdown]
# ### Figure, Axes, Axis, Artist

# %%
# %matplotlib auto
#%matplotlib inline
#fig = plt.figure()  # an empty figure with no Axes
#fig, ax = plt.subplots()  # a figure with a single Axes
#ax.plot([1,2,3],color='red')
#ax.set_xlabel('x label')
fig, axs = plt.subplots(2, 2)  # a figure with a 2x2 grid of Axes
axs[0][0].plot([1,2,3])
axs[1][0].plot([1,2,3],[4,5,6],color='blue',linestyle='dashed')
# Out:
# Using matplotlib backend: MacOSX

# %%
axs[1][1].plot([1,2,3])

# %%
axs[0][1].plot([1,2,3])

# %%
# ?ax.plot

# %%
# %matplotlib inline
x = np.linspace(0, 2, 100)  # Sample data.
# Note that even in the OO-style, we use `.pyplot.figure` to create the Figure.
fig, ax = plt.subplots(figsize=(15, 4))
ax.plot(x, x, label='linear')  # Plot some data on the axes.
ax.plot(x, x**2, label='quadratic')  # Plot more data on the axes...
ax.plot(x, x**3, label='cubic')  # ... and some more.
ax.set_xlabel('x label')  # Add an x-label to the axes.
ax.set_ylabel('y label')  # Add a y-label to the axes.
ax.set_title("Simple Plot")  # Add a title to the axes.
ax.legend();  # Add a legend.

# %%
np.polyfit?

# %%
fig, ax = plt.subplots(figsize=(5, 3))
fig.subplots_adjust(bottom=0.2, left=0.2)
ax.plot([1,2,3])
ax.set_xlabel('time [s] \n This was a long experiment')
ax.set_ylabel(r'$\int\ Y^2\ dt\ \ [V^2 s]$')
plt.show()

# %% [markdown]
# ### Pyplot style

# %%
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2, 100)  # Sample data.
plt.figure(figsize=(8, 4))
plt.plot(x, x, label='linear')  # Plot some data on the (implicit) axes.
plt.plot(x, x**2, label='quadratic')  # etc.
plt.plot(x, x**3, label='cubic')
plt.xlabel('x label')
plt.ylabel('y label')
plt.title("Simple Plot")
plt.legend();

# %%
ax.plot?

# %% [markdown]
# ## 作业示例

# %% [markdown]
# powerlaw
# $f(\lambda)=c*\lambda^\alpha$
#
# $log(f(\lambda))=log(c*\lambda^\alpha)=log(c)+\alpha*log(\lambda)$
#
# n-order polynomial
# $f(x)=a_n*x^n+a_{n-1}*x^{n-1}+...+a_1*x+a_0$
#
# def myfunc($\lambda$,p0,p1,p2....)
#     pass

# %%
#看看拟合出来的参数a是什么
print(a)
# Out:
# [-1.53066655  5.56430778]

# %%
from astropy.io import fits
from matplotlib import pyplot as plt
import numpy as np
spec=fits.open("../data/berk_composte.fits")
hdu0=spec[0]
d=hdu0.data
w=d[0]
f=d[1]

fig,ax=plt.subplots(figsize=(9,5))
ax.set_xscale("log")
ax.set_yscale("log")
ax.plot(w,f)
# array indexing：select the pixels you want
idx=((w>=1350) & (w<=1360)) | ((w>=4200) & (w<=4230))
ax.scatter(w[idx],f[idx],color='red')
#Model fitting: help(np.polyfit)

a=np.polyfit(np.log10(w[idx]),np.log10(f[idx]),1) #y=ax+b
#calculate the fitted values
log10_f1=np.log10(w)*a[0]+a[1]
f1=10**log10_f1
# let's play with the fitted parameters by changing them a bit.
log10_f2=np.log10(w)*(a[0]+0.1)+a[1]-0.35
log10_f3=np.log10(w)*(a[0]-0.1)+a[1]+0.35
f2=10**log10_f2
f3=10**log10_f3
#explore various artist setting using: help(ax.plot)
#different models 
ax.plot(w,f1,'b-',linestyle='dashed')
ax.plot(w,f2,'r-',linestyle='dashed')
ax.plot(w,f3,'g-',linestyle='dashed')

plt.ylim(1,25)
plt.xticks(np.arange(1,10)*1000,np.arange(1,10)*1000)
plt.yticks([0.5,1,5,10],[0.5,1,5,10])
ax.set_xlabel(r"$\mathrm{Wavelength (\AA)}$")
ax.set_ylabel("Flux")
ax.text(1000,1,r"$\alpha_\lambda=-1.4$")

#c.f. https://matplotlib.org/stable/tutorials/text/annotations.html
ax.annotate(r'H$\alpha$', xy=(6563, 5),  xycoords='data',
            xytext=(6563,10), textcoords='data',
            #you could try arrow style here
            arrowprops=dict(arrowstyle='-',facecolor='green') ,
            horizontalalignment='center', verticalalignment='top',
            )
plt.show()
# Out:
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# Title: Composite Quasar Spectra From the Sloan Digital Sky Survey                [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# Authors: Vanden Berk D.E., Richards G.T., Bauer A., Strauss M.A.,                [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# Table: Median Composite Quasar Spectrum                                          [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# ================================================================================ [astropy.io.fits.card]
# WARNING: The following header keyword is invalid or follows an unrecognized non-standard convention:
# ...

# %% [markdown]
# # fitting technique: LMFIT package

# %% [markdown]
# Non-Linear Least-Squares Fitting: Minimize chi-square $\chi^2$ statistic
# ![image.png](attachment:image.png)
# ---
# python中有很多包可以用来做拟合，比如numpy中的polyfit等,scipy中optimize的各种方法，老师个人推荐lmfit包，相对于别的包有如下优势：<BR>
# * 不用管变量的顺序，每个变量都有有意义的名字
# * 很方便的设置变量的上限，下限
# * 很方便的固定某个变量
# * 可以为变量的变化设置数学表达式，如跟别的变量绑定等
# ---
# * 安装lmfit: <BR>
# pip install lmfit<BR>
# __或者__<BR>
# conda install -c conda-forge lmfit
# ---
# * 碰到问题要学会查阅官方文档和里面的例子：
# https://lmfit.github.io/lmfit-py/intro.html
# * 例子里的源代码和数据在这里:
# https://github.com/lmfit/lmfit-py/tree/master/examples

# %% [markdown]
# ## lmfit核心概念: Parameter和Parameters类型

# %%
from lmfit.models import PowerLawModel,GaussianModel
from lmfit import Parameter,Parameters

# %%
#lmfit内置了很多的模型：https://lmfit.github.io/lmfit-py/builtin_models.html
pl_mod=PowerLawModel(prefix='pl_')
# 注意这里的参数pars仅仅是power law模型的参数
pars=pl_mod.guess(f[idx],x=w[idx]) #注意这里的idx是连续谱窗口的数据点
gau_mod=GaussianModel(prefix='g1_')

# %%
#注意pars目前仅仅power law的变量
#https://lmfit.github.io/lmfit-py/parameters.html
pars
# Out:
# Parameters([('pl_amplitude', <Parameter 'pl_amplitude', value=366697.13408339303, bounds=[-inf:inf]>), ('pl_exponent', <Parameter 'pl_exponent', value=-1.5306664689222091, bounds=[-inf:inf]>)])

# %%
#定义模型
mod=pl_mod+gau_mod

# %%
pars
# Out:
# Parameters([('pl_amplitude', <Parameter 'pl_amplitude', value=366697.13408339303, bounds=[-inf:inf]>), ('pl_exponent', <Parameter 'pl_exponent', value=-1.5306664689222091, bounds=[-inf:inf]>)])

# %%
# 根据需要，我们可以设置让某个参数在拟合时不变化
pars['pl_amplitude'].set(vary=False)
pars['pl_exponent'].set(vary=False)

# %%
#把高斯模型的参数update添加到pars中：
pars.update(gau_mod.make_params())
# Out:
# Parameters([('pl_amplitude', <Parameter 'pl_amplitude', value=366697.13408339303 (fixed), bounds=[-inf:inf]>), ('pl_exponent', <Parameter 'pl_exponent', value=-1.5306664689222091 (fixed), bounds=[-inf:inf]>), ('g1_amplitude', <Parameter 'g1_amplitude', value=1.0, bounds=[-inf:inf]>), ('g1_center', <Parameter 'g1_center', value=0.0, bounds=[-inf:inf]>), ('g1_sigma', <Parameter 'g1_sigma', value=1.0, bounds=[0:inf]>), ('g1_fwhm', <Parameter 'g1_fwhm', value=2.35482, bounds=[-inf:inf], expr='2.3548200*g1_sigma'>), ('g1_height', <Parameter 'g1_height', value=0.3989423, bounds=[-inf:inf], expr='0.3989423*g1_amplitude/max(1e-15, g1_sigma)'>)])

# %%
# 根据需要，我们可以设置让某个参数在某个区间内变化
pars['g1_center'].set(value=1549,min=1546,max=1553)
pars['g1_sigma'].set(value=10,min=5,max=20)
pars
# Out:
# Parameters([('pl_amplitude', <Parameter 'pl_amplitude', value=366697.13408339303 (fixed), bounds=[-inf:inf]>), ('pl_exponent', <Parameter 'pl_exponent', value=-1.5306664689222091 (fixed), bounds=[-inf:inf]>), ('g1_amplitude', <Parameter 'g1_amplitude', value=1.0, bounds=[-inf:inf]>), ('g1_center', <Parameter 'g1_center', value=1549, bounds=[1546:1553]>), ('g1_sigma', <Parameter 'g1_sigma', value=10, bounds=[5:20]>), ('g1_fwhm', <Parameter 'g1_fwhm', value=23.5482, bounds=[-inf:inf], expr='2.3548200*g1_sigma'>), ('g1_height', <Parameter 'g1_height', value=0.03989423, bounds=[-inf:inf], expr='0.3989423*g1_amplitude/max(1e-15, g1_sigma)'>)])

# %%
#设置完各种参数的初始值和限制后，真正的拟合在这里
out=mod.fit(f,pars,x=w)

# %%
#画出拟合的结果:residual(残差)和best fit(最佳拟合)
out.plot()

# %%
out.params
# Out:
# Parameters([('pl_amplitude', <Parameter 'pl_amplitude', value=366697.13408339303 (fixed), bounds=[-inf:inf]>), ('pl_exponent', <Parameter 'pl_exponent', value=-1.5306664689222091 (fixed), bounds=[-inf:inf]>), ('g1_amplitude', <Parameter 'g1_amplitude', value=192.03524337257377 +/- 16.9, bounds=[-inf:inf]>), ('g1_center', <Parameter 'g1_center', value=1546.0004455518035 +/- 0.539, bounds=[1546:1553]>), ('g1_sigma', <Parameter 'g1_sigma', value=18.148225028186996 +/- 1.83, bounds=[5:20]>), ('g1_fwhm', <Parameter 'g1_fwhm', value=42.7358032608753 +/- 4.31, bounds=[-inf:inf], expr='2.3548200*g1_sigma'>), ('g1_height', <Parameter 'g1_height', value=4.221403556167375 +/- 0.369, bounds=[-inf:inf], expr='0.3989423*g1_amplitude/max(1e-15, g1_sigma)'>)])

# %%
#根据拟合出来的参数，计算出模型拟合的结果
f_model=out.eval(x=w)

# %%
out.params
# Out:
# Parameters([('pl_amplitude', <Parameter 'pl_amplitude', value=366697.13408339303 (fixed), bounds=[-inf:inf]>), ('pl_exponent', <Parameter 'pl_exponent', value=-1.5306664689222091 (fixed), bounds=[-inf:inf]>), ('g1_amplitude', <Parameter 'g1_amplitude', value=192.03524337257377 +/- 16.9, bounds=[-inf:inf]>), ('g1_center', <Parameter 'g1_center', value=1546.0004455518035 +/- 0.539, bounds=[1546:1553]>), ('g1_sigma', <Parameter 'g1_sigma', value=18.148225028186996 +/- 1.83, bounds=[5:20]>), ('g1_fwhm', <Parameter 'g1_fwhm', value=42.7358032608753 +/- 4.31, bounds=[-inf:inf], expr='2.3548200*g1_sigma'>), ('g1_height', <Parameter 'g1_height', value=4.221403556167375 +/- 0.369, bounds=[-inf:inf], expr='0.3989423*g1_amplitude/max(1e-15, g1_sigma)'>)])

# %%
pl_pars=Parameters()
pl_pars.add_many(out.params['pl_amplitude'],out.params['pl_exponent'])
pl_model=pl_mod.eval(pl_pars,x=w)
pl_pars
# Out:
# Parameters([('pl_amplitude', <Parameter 'pl_amplitude', value=366697.13408339303 (fixed), bounds=[-inf:inf]>), ('pl_exponent', <Parameter 'pl_exponent', value=-1.5306664689222091 (fixed), bounds=[-inf:inf]>)])

# %%
gau_pars
# Out:
# Parameters([('g1_amplitude', <Parameter 'g1_amplitude', value=192.03524337257377 +/- 16.9, bounds=[-inf:inf]>), ('g1_center', <Parameter 'g1_center', value=1546.0004455518035 +/- 0.539, bounds=[1546:1553]>), ('g1_sigma', <Parameter 'g1_sigma', value=18.148225028186996 +/- 1.83, bounds=[5:20]>)])

# %%
gau_pars=Parameters()
gau_pars.add_many(out.params['g1_amplitude'],out.params['g1_center'],out.params['g1_sigma'])
gau_model=gau_mod.eval(gau_pars,x=w)
plt.plot(w,gau_model)

# %%
#另外一种计算模型结果的方法
gau_model1=gau_mod.eval(out.params,x=w)
plt.plot(w,gau_model1)

# %%
# %matplotlib inline
fig,ax=plt.subplots(figsize=(9,5))
ax.set_xscale("log")
ax.set_yscale("log")
ax.plot(w,f)
#模型拟合的结果再这里
ax.plot(w,f_model,'b-',linestyle='dashed')
ax.plot(w,pl_model,'r-',linestyle='dashed')
ax.plot(w,gau_model,'g-',linestyle='dashed')
plt.ylim(1,25)
plt.xticks(np.arange(1,10)*1000,np.arange(1,10)*1000)
plt.yticks([0.5,1,5,10],[0.5,1,5,10])
ax.set_xlabel(r"$\mathrm{Wavelength (\AA)}$")
ax.set_ylabel("Flux")
ax.text(1000,1,r"$\alpha_\lambda=-1.4$")

#c.f. https://matplotlib.org/stable/tutorials/text/annotations.html
ax.annotate(r'H$\alpha$', xy=(6563, 5),  xycoords='data',
            xytext=(6563,10), textcoords='data',
            #you could try arrow style here
            arrowprops=dict(arrowstyle='-',facecolor='green') ,
            horizontalalignment='center', verticalalignment='top',
            )
plt.show()

# %% [markdown]
# ## Using Mathematical Constraints in lmfit
# https://lmfit.github.io/lmfit-py/constraints.html

# %%
pars = Parameters()
pars.add('amp_1', value=0.5, min=0, max=1)
pars.add('cen_1', value=2.2)
pars.add('wid_1', value=0.2)
pars
# Out:
# Parameters([('amp_1', <Parameter 'amp_1', value=0.5, bounds=[0:1]>), ('cen_1', <Parameter 'cen_1', value=2.2, bounds=[-inf:inf]>), ('wid_1', <Parameter 'wid_1', value=0.2, bounds=[-inf:inf]>)])

# %%
#constraint here
#通过设置constraint，我们可以绑定两个变量
pars.add('amp_2', expr='(2.0 - amp_1**2)')
pars.add('wid_2', expr='sqrt(pi)*wid_1')
pars.add('cen_2', expr='cen_1 * wid_2 / max(wid_1, 0.001)')
pars
# Out:
# Parameters([('amp_1', <Parameter 'amp_1', value=0.5, bounds=[0:1]>), ('cen_1', <Parameter 'cen_1', value=2.2, bounds=[-inf:inf]>), ('wid_1', <Parameter 'wid_1', value=0.2, bounds=[-inf:inf]>), ('amp_2', <Parameter 'amp_2', value=1.75, bounds=[-inf:inf], expr='(2.0 - amp_1**2)'>), ('wid_2', <Parameter 'wid_2', value=0.3544907701811032, bounds=[-inf:inf], expr='sqrt(pi)*wid_1'>), ('cen_2', <Parameter 'cen_2', value=3.8993984719921353, bounds=[-inf:inf], expr='cen_1 * wid_2 / max(wid_1, 0.001)'>)])

# %%
pars.add('param_a', value=1)
pars.add('param_b', value=2)
pars.add('test_val', value=100)

pars.add('bounded', expr='param_a if test_val/2. > 100 else param_b')
pars
# Out:
# Parameters([('amp_1', <Parameter 'amp_1', value=0.5, bounds=[0:1]>), ('cen_1', <Parameter 'cen_1', value=2.2, bounds=[-inf:inf]>), ('wid_1', <Parameter 'wid_1', value=0.2, bounds=[-inf:inf]>), ('amp_2', <Parameter 'amp_2', value=1.75, bounds=[-inf:inf], expr='(2.0 - amp_1**2)'>), ('wid_2', <Parameter 'wid_2', value=0.3544907701811032, bounds=[-inf:inf], expr='sqrt(pi)*wid_1'>), ('cen_2', <Parameter 'cen_2', value=3.8993984719921353, bounds=[-inf:inf], expr='cen_1 * wid_2 / max(wid_1, 0.001)'>), ('param_a', <Parameter 'param_a', value=1, bounds=[-inf:inf]>), ('param_b', <Parameter 'param_b', value=2, bounds=[-inf:inf]>), ('test_val', <Parameter 'test_val', value=100, bounds=[-inf:inf]>), ('bounded', <Parameter 'bounded', value=2, bounds=[-inf:inf], expr='param_a if test_val/2. > 100 else param_b'>)])

# %% [markdown]
# ## 模型：另外一个lmfit的核心概念
# * https://lmfit.github.io/lmfit-py/model.html
# * built-in models: https://lmfit.github.io/lmfit-py/builtin_models.html
# * lmfit自定义模型拟合

# %%
import matplotlib.pyplot as plt
from numpy import exp, loadtxt, pi, sqrt

from lmfit import Model

data = loadtxt('../data/model1d_gauss.dat')
x = data[:, 0]
y = data[:, 1]


def gaussian(x, amp, cen, wid):
    """1-d gaussian: gaussian(x, amp, cen, wid)"""
    return (amp / (sqrt(2*pi) * wid)) * exp(-(x-cen)**2 / (2*wid**2))

#注意这里的函数定义：
#第一个参数（这里的x)默认是自变量
#后面的参数和关键字（这里的amp,cen,wid)默认为模型的参数

# %%
plt.plot(x,y)

# %%
gmodel = Model(gaussian)

# %%
gmodel?

# %%
result = gmodel.fit(y, x=x, amp=5, cen=5, wid=1)

print(result.fit_report())
# Out:
# [[Model]]
#     Model(gaussian)
# [[Fit Statistics]]
#     # fitting method   = leastsq
#     # function evals   = 33
#     # data points      = 101
#     # variables        = 3
#     chi-square         = 3.40883599
#     reduced chi-square = 0.03478404
#     Akaike info crit   = -336.263713
#     Bayesian info crit = -328.418352
# [[Variables]]
#     amp:  8.88021830 +/- 0.11359493 (1.28%) (init = 5)
#     cen:  5.65866102 +/- 0.01030495 (0.18%) (init = 5)
#     wid:  0.69765468 +/- 0.01030495 (1.48%) (init = 1)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(amp, wid) = 0.577

# %%
result.init_fit

# %%
plt.plot(x, y, 'o')
plt.plot(x, result.init_fit, '--', label='initial fit')
plt.plot(x, result.best_fit, '-', label='best fit')
plt.legend()
plt.show()
# <end examples/doc_model_gaussian.py>

# %%
result.params
# Out:
# Parameters([('amp', <Parameter 'amp', value=8.880218295745673 +/- 0.114, bounds=[-inf:inf]>), ('cen', <Parameter 'cen', value=5.658661022810115 +/- 0.0103, bounds=[-inf:inf]>), ('wid', <Parameter 'wid', value=0.6976546811372576 +/- 0.0103, bounds=[-inf:inf]>)])

# %% [markdown]
# # Download SDSS QSO spectra
# 1. Explorer: https://skyserver.sdss.org/dr17
# 2. Download SDSS spectra(spec-6173-56238-0528.fits) https://data.sdss.org/sas/dr17/eboss/spectro/redux/v5_13_2/spectra/full/ https://data.sdss.org/sas/dr17/eboss/spectro/redux/v5_13_2/spectra/lite/
# 3. Please read sdss spectrum data model：
# https://data.sdss.org/datamodel/files/BOSS_SPECTRO_REDUX/RUN2D/spectra/PLATE4/spec.html
# ![image.png](attachment:0f937e0c-3836-453d-8337-a17f9c9a9db4.png)

# %%
import matplotlib.pyplot as plt
import numpy as np
from astropy.io import fits
from scipy.signal import savgol_filter
# %matplotlib inline

# %%
hdulist=fits.open('../data/spec-6173-56238-0528.fits')
spec=hdulist[1].data
plt.figure(figsize=(8,5)) #change figure size
wave=10**spec['loglam']
flux=spec['flux']
flux_smooth=savgol_filter(spec['flux'], 51, 3)
flux_model=spec['model']
# plt.plot(10**spec['loglam'],spec['flux'],10**spec['loglam'],flux_smooth,10**spec['loglam'],spec['model'])
plt.plot(wave,flux,wave,flux_smooth,wave,flux_model)
plt.ylim(-1,5)
plt.show()

# %%
hdus2226=fits.open("../data/spec-5043-56187-0557.fits")
spec2226=hdus2226[1].data
wave2226=10**spec2226['loglam']
flux2226=spec2226['flux']
flux2226_model=spec2226['model']
flux2226_smooth=savgol_filter(spec2226['flux'], 31, 3)

plt.figure(figsize=(8,5))
plt.plot(wave2226,flux2226,wave2226,flux2226_smooth,wave2226,flux2226_model)
plt.ylim(0,20)
plt.xlim(7000,9000)
plt.show()

# %%
fig,ax=plt.subplot()
ax.plot(wave2226,flux2226,wave2226,flux_2226_model)
plt.show()

# %% [markdown]
# ## signal to noise ratio

# %%
error=1/np.sqrt(spec['ivar'])
sn=flux/error
plt.plot(wave,sn)
plt.xlim(3600,5000)
# index Ca II region: Ca II 3934,3969
idx=((wave>=3930) & (wave<=3975))
plt.plot(wave[idx],sn[idx],c='r')
# Out:
# /srv/conda/envs/notebook/lib/python3.7/site-packages/ipykernel_launcher.py:1: RuntimeWarning: divide by zero encountered in true_divide
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # 作业:
# 1. 改写示例程序中的np.polyfit，使用lmfit包来拟合图3中的power law.
# 2. 随机下载两条SDSS QSO光谱，使用lmfit来同时拟合Ca II and Na I 吸收线。
#     * Ca II doublet at  3934.77, 3969.59 (K, H), and the Na I D doublet at  5891.58, 5897.56 (D2, D1)，每条线可以用一个Gauss成分描述。
#     * 在速度空间(log($\lambda$)),四个Gauss成分的宽度应绑定；线心移动（$\frac{{\rm dv}}{c}=\frac{d\lambda}{\lambda}={\rm dlog}\lambda$）应绑定；宽度，线心移动速度范围（不太大，也不太小，经验中调整）需要在lmfit中设置（<5 $\unicode{x212B}$)。
#     * 注意我们目前是形式上拟合一个吸收线的强度，目标是选取吸收线强度大的。大部分类星体中没有这些吸收线，拟合得到的高斯应理解为吸收线强度的上限。
# 3. 在overleaf上协同开展论文写作。
